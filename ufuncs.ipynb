# %% [markdown]
# <a href="https://colab.research.google.com/github/tormenteddave/thisisdavespublic/blob/main/ufuncs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Rough Sine Wave

# %%
# 10 points, starting at 0 and ending at 2PI or 6.28ish
x = np.linspace(0, 2 * np.pi, 10)
print(x)
# Out:
# [0.         0.6981317  1.3962634  2.0943951  2.7925268  3.4906585
#  4.1887902  4.88692191 5.58505361 6.28318531]

# %%
y = np.sin(x)
print(y)
# Out:
# [ 0.00000000e+00  6.42787610e-01  9.84807753e-01  8.66025404e-01
#   3.42020143e-01 -3.42020143e-01 -8.66025404e-01 -9.84807753e-01
#  -6.42787610e-01 -2.44929360e-16]

# %%
plt.plot(x, y)

# %% [markdown]
# # Smooth Sine Wave

# %%
resolution = 100
frequency = 2
x = np.linspace(0, 2 * np.pi, resolution)
y = np.sin(x * frequency)
plt.plot(x, y)

# %% [markdown]
# # Multiple Sine Wave

# %%
y1 = np.sin(x * 6)
y2 = np.sin(x * 9)
plt.plot(x, y1 + y2)
