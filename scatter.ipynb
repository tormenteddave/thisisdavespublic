# %% [markdown]
# <a href="https://colab.research.google.com/github/tormenteddave/thisisdavespublic/blob/main/scatter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num = 20
# two-dimensional data array
data = np.random.rand(4, num)
print(data)
# Out:
# [[0.02252003 0.24715107 0.15559203 0.66746413 0.29176049 0.23173683
#   0.92596474 0.71258982 0.44851686 0.11110896 0.60792999 0.0861328
#   0.43417021 0.18887728 0.60721157 0.35088699 0.24185475 0.33580183
#   0.40494581 0.70399803]
#  [0.67958144 0.9699347  0.1354196  0.59879065 0.08791182 0.01478837
#   0.76947501 0.64829271 0.08264837 0.0667784  0.9787849  0.88807495
#   0.04249941 0.88088307 0.31387341 0.21964788 0.49425177 0.53722666
#   0.69206954 0.27705564]
#  [0.78386841 0.67401186 0.5267167  0.51861114 0.59725105 0.08019311
#   0.14982642 0.56648366 0.44585215 0.93399284 0.22285334 0.22258626
#   0.81508125 0.13830674 0.965041   0.39907726 0.98121942 0.5758187
#   0.70027766 0.26094898]
#  [0.07927392 0.96901317 0.06405701 0.66428511 0.04805859 0.89533211
#   0.76198561 0.92611053 0.21546864 0.88551561 0.18859784 0.94689229
#   0.54653162 0.47393046 0.88367311 0.1978639  0.26512065 0.54500872
#   0.42651094 0.5296007 ]]

# %%
plt.scatter(data[0], data[1], c=data[2], s=data[3]*1000, alpha=.3, cmap='viridis')
plt.colorbar()  # show color scale

# %%
num = 500
data = np.random.rand(num, num)
plt.imshow(data, cmap='binary')
plt.colorbar()
